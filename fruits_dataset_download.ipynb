# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"orange fruit, rotten orange fruit",
             "limit":100,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = orange fruit
# Evaluating...
# Starting Download...
# Completed Image ====> 1.oranges_-_whole-halved-segment.jpg
# Completed Image ====> 2.50913eeb04768a5b1fa9985c16704d96.jpg
# Completed Image ====> 3.orange-500x500.jpg
# Completed Image ====> 4.orange-picture-id185284489.jpg
# Completed Image ====> 5.oranges.jpg
# Completed Image ====> 6.05795a16b647118ffb6629390e995adb.jpg
# Completed Image ====> 7.difference-between-tangerines-oranges-1296x728.jpg
# Completed Image ====> 8.__opt__aboutcom__coeus__resources__content_migration__mnn__images__2019__04__oranges_pith_peels-0fe5ff335016464e878db92d02d9f5ab.jpg
# Completed Image ====> 9.img_9250.jpg
# Completed Image ====> 10.01_oranges_finally%e2%80%94here%e2%80%99s-which-%e2%80%9corange%e2%80%9d-came-first-the-color-or-the-fruit_691064353_lucky-business-1024x683.jpg
# Completed Image ====> 11.orange-600x600-500x500.jpg
# Completed Image ====> 12.orange-fruit-powder-100-gms.jpg
# ...

# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"mango fruit, rotten mango fruit",
             "limit":100,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = mango fruit
# Evaluating...
# Starting Download...
# Completed Image ====> 1.mango-fruit-500x500.jpg
# Completed Image ====> 2.1256.750@2x.jpg
# Completed Image ====> 3.220px-hapus_mango.jpg
# Completed Image ====> 4.54522547-mango-cubes-and-mango-fruit-isolated-on-a-white-background-.jpg
# Completed Image ====> 5.closeup-of-mango-fruit-on-a-mango-tree-picture-id1202424449.jpg
# Completed Image ====> 6.health-benefits-of-mango-700-350-63441b3.jpg
# Completed Image ====> 7.130391747-isolated-mango-two-yellow-mango-fruit-hanging-on-a-tree-branch-isolated-on-white-background.jpg
# Completed Image ====> 8.mango_hd_images_background.jpg
# Completed Image ====> 9.mango.jpg
# Completed Image ====> 10.mangoes-cover-1.jpg
# Completed Image ====> 11.mango.jpg
# Completed Image ====> 12.mango-1-723x400.jpg
# Completed Image ====> 13.0008d9cf34b03fa7a7eb3c1a95b2e78e.jpg
# ...

# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"potato vegetable, rotten potato vegetable",
             "limit":100,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = potato vegetable
# Evaluating...
# Starting Download...
# Completed Image ====> 1.potatoes-500x500.jpg
# Completed Image ====> 2.nutritional-difference-of-potatoes-1180x560.jpg
# Completed Image ====> 3.potato-500x500.jpeg
# Completed Image ====> 4.image.jpg
# Completed Image ====> 5.6d1b47dd92f24278.jpg
# Completed Image ====> 6.images_potatohealthy-660x330.jpg
# Completed Image ====> 7.main-qimg-94ca06f6d5627589c320691005694459.webp
# Completed Image ====> 8.potatoes-1594205506.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)>
# Completed Image ====> 9.patates.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)>
# Completed Image ====> 10.pomme-de-terre_000.jpg
# ...

# %%
from google_images_download import google_images_download

#instantiate the class
response = google_images_download.googleimagesdownload()
arguments = {"keywords":"onion vegetable, rotten onion vegetable",
             "limit":100,"print_urls":False}
paths = response.download(arguments)

#print complete paths to the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = onion vegetable
# Evaluating...
# Starting Download...
# Completed Image ====> 1.fresh-red-onion-500x500.jpg
# Completed Image ====> 2.132b1227d6c5595567801000b04dbda4.jpg
# Completed Image ====> 3.onion.jpg
# Completed Image ====> 4.fotolia_61211686_subscription_xl-copy.jpg
# Completed Image ====> 5.73108379.cms.jpg
# Completed Image ====> 6.fresh-onion-500x500.jpg
# Completed Image ====> 7.10000148-3_1-fresho-onion.jpg
# Completed Image ====> 8.onion-red.jpg
# Completed Image ====> 9.128183679onion2011505738229.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)>
# Completed Image ====> 10.nurserylive-seeds-spring-cut-bunching-onion-vegetable-seeds-16969121366156.jpg
# Completed Image ====> 11.onion.jpg
# ...

# %%
# !ls
# Out:
# README.md                   google_image_download.ipynb
# console.js                  requirements.txt
# download_images.py          urls.txt
# downloads

# %%
# Out:
#  rotten mango fruit       rotten potato vegetable orange fruit
#  rotten onion vegetable  mango fruit              potato vegetable
#  rotten orange fruit     onion vegetable
